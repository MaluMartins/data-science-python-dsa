# %%
import pandas as pd

# %%
# carrega o arquivo para um dataframe pandas
dados = pd.read_csv("Credit.csv")
dados.shape # formato da tabela (linhas, colunas)
# Out:
# (1000, 21)

# %%
# resumo estatístico das colunas numéricas
dados.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# primeiros registros
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# últimos registros
dados.tail(3) # mostra os últimos 3 registros
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 997   'no checking'        12                   'existing paid'    radio/tv
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 997            804           <100         >=7                       4
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 997   'male single'          none  ...                  car  38
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# ...

# %%
# mostrar dados por nome da coluna
dados[["purpose"]]
# Out:
#                  purpose
# 0               radio/tv
# 1               radio/tv
# 2              education
# 3    furniture/equipment
# 4              'new car'
# ..                   ...
# 995  furniture/equipment
# 996           'used car'
# 997             radio/tv
# 998             radio/tv
# 999           'used car'
#
# [1000 rows x 1 columns]

# %%
# mostrando dados pelo índice
dados.loc[1:3] # mostra linhas de 1 a 3
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
dados.loc[[1,3]] # mostra linhas 1 E 3
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
dados.loc[dados["purpose"] == "radio/tv"] #mostra linhas onde o valor de purpose é radio/tv
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
dados.loc[dados['credit_amount'] > 18000] #mostra linhas onde o valor de credit amount é maior que 18k
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
# criando outro DataFrame
credit2 = dados[['checking_status','duration']].loc[dados['credit_amount'] > 18000] #apenas as colunas checking status e duration apenas onde o valor de credit amount é maior que 18k
print(credit2)
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
# séries do pandas (coluna única)
s1 = pd.Series([12,3,0,98,5,13])
print(s1)
type(s1)
# Out:
# 0    12
# 1     3
# 2     0
# 3    98
# 4     5
# 5    13
# dtype: int64
# pandas.core.series.Series

# %%
s2 = dados['purpose']
print(s2)
type(s2)
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# pandas.core.series.Series

# %%
df_purpose = dados[['purpose']]
print(df_purpose)
type(df_purpose)
# Out:
#                  purpose
# 0               radio/tv
# 1               radio/tv
# 2              education
# 3    furniture/equipment
# 4              'new car'
# ..                   ...
# 995  furniture/equipment
# 996           'used car'
# 997             radio/tv
# 998             radio/tv
# 999           'used car'
#
# [1000 rows x 1 columns]
# pandas.core.frame.DataFrame

# %%
#renomear
dados.rename(columns={"duration":"duração","purpose":"propósito"})
# Out:
#     checking_status  duração                    credit_history  \
# 0                <0        6  'critical/other existing credit'
# 1          0<=X<200       48                   'existing paid'
# 2     'no checking'       12  'critical/other existing credit'
# 3                <0       42                   'existing paid'
# 4                <0       24              'delayed previously'
# ..              ...      ...                               ...
# 995   'no checking'       12                   'existing paid'
# 996              <0       30                   'existing paid'
# 997   'no checking'       12                   'existing paid'
# 998              <0       45                   'existing paid'
# 999        0<=X<200       45  'critical/other existing credit'
#
#                propósito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...
